# %% [markdown]
# # Primeiro trabalho prático

# %% [markdown]
# ## Parte teórica (4 pontos cada)

# %% [markdown]
# Classifique as afirmações em Verdadeiro ou Falso, justifique as afirmativas falsas

# %% [markdown]
# 1 - As imagens matricias são mais usadas em logos, pois não apresentam serrilhamento quando são ampliadas

# %%
print("Falso. Imagens matriciais não são utilizadas em logos de empresas, pois elas perdem qualidade quando redimensionadas.\n" \
"Em vez disso, geralmente opta-se por logos vetoriais, que podem ser redimensionados sem perda de qualidade.")
# Out:
# Falso. Imagens matriciais não são utilizadas em logos de empresas, pois elas perdem qualidade quando redimensionadas.
# Em vez disso, geralmente opta-se por logos vetoriais, que podem ser redimensionados sem perda de qualidade.

# %% [markdown]
# 2 - Códigos feitos a mão e no Numpy levam o mesmo tempo para rodar, usamos o Numpy apenas por convêniencia

# %%
print("Falso. Preferimos código feitos com numpy do que à mão porque o numpy é otimizado para desempenho e eficiência, \n" \
"além de oferecer uma ampla gama de funções matemáticas e operações vetorizadas que facilitam o desenvolvimento de código \n"
"Garantindo praticidade para a execução de operações que seriam muito mais complexas e lentas manualmente.")
# Out:
# Falso. Preferimos código feitos com numpy do que à mão porque o numpy é otimizado para desempenho e eficiência,
# além de oferecer uma ampla gama de funções matemáticas e operações vetorizadas que facilitam o desenvolvimento de código
# Garantindo praticidade para a execução de operações que seriam muito mais complexas e lentas manualmente.

# %% [markdown]
# 3 - Um dos usos do histograma é realizar conversões entre os espaços de cores

# %%
print("Falso. Histogramas são usados para representar a distribuição de intensidade de pixels em uma imagem, \n" \
"mas não realizam conversões entre espaços de cor. Conversões entre espaços de cor são realizadas por funções específicas \n" \
"que transformam as representações de cor, como RGB para HSV")
# Out:
# Falso. Histogramas são usados para representar a distribuição de intensidade de pixels em uma imagem,
# mas não realizam conversões entre espaços de cor. Conversões entre espaços de cor são realizadas por funções específicas
# que transformam as representações de cor, como RGB para HSV

# %% [markdown]
# 4 - O código abaixo é usado para importar uma imagem e retirar o terceiro campo de cor (Blue, ou azul, do RGB)
#
# ```imagem = np.array(Image.open('Clara.png'))[:, :, :3]```

# %%
print("Falso, a imagem é importada corretamente, porém o campo retirado é o canal alpha e não o canal azul do RGB \n")
# Out:
# Falso, a imagem é importada corretamente, porém o campo retirado é o canal alpha e não o canal azul do RGB

# %% [markdown]
# 5 - Utilizamos técnicas como HDR para melhorar a iluminação de imagens

# %%
print("Verdadeiro. O HDR é uma técnica que permite capturar e depois exibir maiores faixas de luminosidadee \n" \
"em uma imagem, o que resulta em imagens mais realistas e detalhadas, especialmente em cenas com alto contraste entre luz e sombra.")
# Out:
# Verdadeiro. O HDR é uma técnica que permite capturar e depois exibir maiores faixas de luminosidadee
# em uma imagem, o que resulta em imagens mais realistas e detalhadas, especialmente em cenas com alto contraste entre luz e sombra.

# %% [markdown]
# 6 - O espaço de cores RGB é amplamente utilizado pois é o mais intuitivo para seres humanos

# %%
print("Falso. Apesar de o RGB ser um dos mais utilizado, ele não é o mais intuitivo para manipulação de cor,\n" \
"pois o modelo RGB baseia-se na representação das cores por uma combinação de outras 3  \n" \
"Modelos como HSV são frequentemente considerados mais intuitivos para manipulação de cor, \n" \
"pois separam a tonalidade, saturação e valor/luminosidade, facilitando a compreensão e ajuste das cores.")
# Out:
# Falso. Apesar de o RGB ser um dos mais utilizado, ele não é o mais intuitivo para manipulação de cor,
# pois o modelo RGB baseia-se na representação das cores por uma combinação de outras 3
# Modelos como HSV são frequentemente considerados mais intuitivos para manipulação de cor,
# pois separam a tonalidade, saturação e valor/luminosidade, facilitando a compreensão e ajuste das cores.

# %% [markdown]
# 7 - Imagens vetoriais apresentam serrilhamento quando são ampliadas

# %%
print("Falso. Imagens vetoriais não apresentam serrilhado, pois são baseadas em formas geométricas e não em pixels\n" \
"Imagens matriciais, por outro lado, podem apresentar serrilhado quando redimensionadas")
# Out:
# Falso. Imagens vetoriais não apresentam serrilhado, pois são baseadas em formas geométricas e não em pixels
# Imagens matriciais, por outro lado, podem apresentar serrilhado quando redimensionadas

# %% [markdown]
# 8 -  A lógica XOR aplicada em uma imagem detecta os pixels que mudaram de valor

# %%
print("Verdadeiro. Ao aplicar o XOR entre duas imagens, os pixels que são diferentes entre as duas imagens \n" \
"resultam em um valor de pixel diferente de zero. \n" \
"Enquanto os pixels que são iguais resultam em um valor de pixel igual a zero.")
# Out:
# Verdadeiro. Ao aplicar o XOR entre duas imagens, os pixels que são diferentes entre as duas imagens
# resultam em um valor de pixel diferente de zero.
# Enquanto os pixels que são iguais resultam em um valor de pixel igual a zero.

# %% [markdown]
# 9 -  A lógica XOR aplicada em uma imagem detecta os pixels que mudaram de valor

# %%
print("Obs: Questão 9 IGUAL à questão 8: \n" \
"Verdadeiro. Ao aplicar o XOR entre duas imagens, os pixels que são diferentes entre as duas imagens \n" \
"resultam em um valor de pixel diferente de zero. \n" \
"Enquanto os pixels que são iguais resultam em um valor de pixel igual a zero.")
# Out:
# Obs: Questão 9 IGUAL à questão 8:
# Verdadeiro. Ao aplicar o XOR entre duas imagens, os pixels que são diferentes entre as duas imagens
# resultam em um valor de pixel diferente de zero.
# Enquanto os pixels que são iguais resultam em um valor de pixel igual a zero.

# %% [markdown]
# 10 - Bordas são mudanças drásticas de iluminação na imagem

# %%
print("Verdadeiro. Bordas são marcadas por uma mudança abrupta na intensidade de pixel \n" \
"e podem ser detectadas usando técnicas de processamento de imagem")
# Out:
# Verdadeiro. Bordas são marcadas por uma mudança abrupta na intensidade de pixel
# e podem ser detectadas usando técnicas de processamento de imagem

# %% [markdown]
# # Parte prática (5 pontos cada, exceto a questão 11 que vale 10)

# %% [markdown]
# ## Material de apoio

# %% [markdown]
# ### Importações
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
# from PIL import Image
# ```
#
# ### Manipulação de imagens
#
# ```python
# img = Image.open('nome.extensão')
# img = np.array(Image.open('nome.extensão'))
# img = img[:, :, :3]
# img_pil = Image.fromarray(img_np)
# img.save('nome.png')
# Image.fromarray(img).save('nome_arquivo.extensao')
# (l,c,p) = img.shape
# ```
#
# ### Greyscale
#
# #### Algoritmo genérico, substituir o método escolhido
# ```python
# img_avg = np.zeros(shape=(l, c), dtype=np.uint8)
# for i in range(l):
#     for j in range(c):
#         r = float(img_np[i, j, 0])
#         g = float(img_np[i, j, 1])
#         b = float(img_np[i, j, 2])
#
#         img_avg[i, j] = (aplicar método)
# ```
#
# #### Métodos:
#
#
# Lightness: $\frac{max(R,G,B)+min(R,G,B)}{2}$
#
#
# Average: $\frac{R+G+B}{3}$
#
#
# Luminosity: $0.2126 \cdot R + 0.7152 \cdot G + 0.0722 \cdot B$
#
#
# RGB para CMY:
# ### <font color="red">R</font><font color="green">G</font><font color="blue">B</font> para <font color="cyan">C</font><font color="magenta">M</font><font color="yellow">Y</font>
# $$\begin{pmatrix}
#     C \\ M \\ Y
# \end{pmatrix} = \begin{pmatrix}
#     1 \\ 1 \\ 1
# \end{pmatrix} - \begin{pmatrix}
#     R \\ G \\ B
# \end{pmatrix} e \begin{pmatrix}
#     R \\ G \\ B
# \end{pmatrix} = \begin{pmatrix}
#     1 \\ 1 \\ 1
# \end{pmatrix} - \begin{pmatrix}
#     C \\ M \\ Y
# \end{pmatrix}$$
# * **<font color="red">R</font>** + **<font color="cyan">C</font>** = 1 (ou 255);
# * **<font color="green">G</font>** + **<font color="magenta">M</font>** = 1;
# * **<font color="blue">B</font>** + **<font color="yellow">Y</font>** = 1.
#
#
# Interpolação Bilinear:
# Seja $I$ a imagem de entrada $L_{entrada}×C_{entrada}$ e $J$ a imagem de saída $L_{saída}×C_{saída}.$
#
# Seja $s_L = L_{entrada}/L_{saída}$ e $s_C = C_{entrada}/C_{saída}.$
#
# Seja $l_f = l \cdot s_L$ para $r=0,\ldots,R_{saída}-1$ e $c_f = c \cdot s_C$ para $c=0,\ldots,C_{saída}-1.$
#
# Seja $r_0 = \lfloor{l_f}\rfloor$ e $c=\lfloor{c_f}\rfloor.$
#
# Seja $\Delta_l = l_f - l_0$ e $\Delta_c = c_f - c_0.$
#
# Então $J(l, c)$
# $$=I(l_0, c_0) \cdot (1-\Delta_l) \cdot (1-\Delta_c)$$
# $$+I(l_0+1, c_0) \cdot \Delta_l \cdot (1-\Delta_c)$$
# $$+I(l_0, c_0+1) \cdot (1-\Delta_l) \cdot \Delta_c$$
# $$+I(l_0+1, c_0+1) \cdot \Delta_l \cdot \Delta_c.$$
#
# ### Escalonamento com nearest neighbor
#
# ```python
# ls, cs = l * sy, c * sx
# mario_nn = np.zeros(shape=(ls, cs, p), dtype=np.uint8)
#
# for i in range(ls):
#     for j in range(cs):
#         new_y = int(np.floor(i * (l / ls)))
#         new_x = int(np.floor(j * (c / cs)))
#
#         mario_nn[i, j] = mario[new_y, new_x]
# ```
# ### Escalonamento clássico
# ```python
# scale_x, scale_y = 2, 2
# mario_scale = np.zeros(shape=(l * scale_y, c * scale_x, p), dtype=np.uint8)
# for i in range(l):
#     for j in range(c):
#         new_x = np.round(j * scale_x)
#         new_y = np.round(i * scale_y)
#         mario_scale[new_y, new_x] = mario[i, j]
#
# plt.imshow(mario_scale)
# Image.fromarray(mario_scale).save('mario_scale.png')
# ```
#
# ### Cisalhamento
#
# ```python
# img_shear = np.zeros((int(l * (1.1 + cy)), int(c * (1.1 + cx)), p), dtype=np.uint8)
# for i in range(l):
#     for j in range(c):
#         new_x = int(j + cx * i)
#         new_y = int(cy * j + i)
#
#         img_shear[new_y, new_x] = img[i, j]
# ```
#
# ### Imagem grayscale para imagem binária de 3 canais
#
# ```python
# bin = np.zeros(shape=(l,c,3),dtype=np.uint8)
#
# for i in range(l):
#     for j in range(c):
#         if img[i,j] > thresh:
#             bin[i,j,:] = 255
#         else:
#             bin[i,j,:] = 0
#
# ```
# ### Blending com escala genérica
#
# ```python
# imagem_blending = (C * img_1) + ((1 - C) * img_2)
# imagem_blending = imagem_blending.astype(np.uint8)
# ```
#
# ### Histograma
# ```python
# def histogram_gray(img):
#     (l, c) = img.shape
#     histogram = np.zeros(256, dtype=np.int32)
#
#     for i in range(l):
#         for j in range(c):
#             intensity = img[i, j]
#             histogram[intensity] += 1
#
#     return histogram
#
# def show_histogram_gray(img):
#     histogram = histogram_gray(img)
#     plt.figure(figsize=(16, 16))
#     plt.subplot(2, 1, 1)
#     plt.imshow(img, cmap='gray', vmin=0, vmax=255)
#     plt.subplot(2, 1, 2)
#     plt.bar(range(256), histogram)
#
# def show_histogram(img):
#     histogram_r = histogram_gray(img[:, :, 0])
#     histogram_g = histogram_gray(img[:, :, 1])
#     histogram_b = histogram_gray(img[:, :, 2])
#
#     plt.figure(figsize=(16, 16))
#     plt.subplot(2, 1, 1)
#     plt.imshow(img, cmap='gray', vmin=0, vmax=255)
#     plt.subplot(2, 1, 2)
#     plt.bar(range(256), histogram_r, color='red')
#     plt.bar(range(256), histogram_g, color='green')
#     plt.bar(range(256), histogram_b, color='blue')
#
# ```
# ### Espelhamento
# ```python
# refl = np.zeros(shape=example.shape, dtype=np.uint8)
# for i in range(l):
#     for j in range(c):
#         new_x = -j
#         new_y = i
#         refl[new_y, new_x] = example[i, j]
#
# plt.imshow(refl)
# ```
#
#
# No outro eixo
#
# ```python
# refl = np.zeros(shape=example.shape, dtype=np.uint8)
# refl[::-1, ::1] = example
# plt.imshow(refl)
# ```
#
# ### Detecção de bordas
# ```python
# abs_tg_c = np.abs(np.diff(museum.astype(np.float64), axis=0, append=255))
#
# abs_tg_l = np.abs(np.diff(museum.astype(np.float64), axis=1, append=255))
#
# abs_tg = np.sqrt(abs_tg_c ** 2 + abs_tg_l ** 2)
#
# threshold = 16
# museum_border = np.zeros(shape=(l, c), dtype=np.uint8)
# museum_border[abs_tg > threshold] = 255
# ```
#
# ### Operações lógicas
# NOT:
# ```python
# bin1_not = np.bitwise_not(bin1)
# bin2_not = np.invert(bin2)
# ```
# AND:
# ```python
# bin_and = np.bitwise_and(bin1, bin2)
# ```
# OR:
# ```python
# bin_or = np.bitwise_or(bin1, bin2)
# ```
# XOR
# ```python
# bin_xor = np.bitwise_xor(bin1, bin2)
# ```

# %% [markdown]
# **1 -** Importe as bibliotecas que serão usadas

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# **2 -** Abra as imagens techno.jpg, Shrine.jpg e Ninja.jpg, retire o canal alpha se necessário, exiba essas imagens e mostre o formato de cada uma

# %%
techno = np.array(Image.open('techno.jpg'))

shrine = np.array(Image.open('shrine.jpg'))

ninja = np.array(Image.open('ninja.jpg'))

def plot_images(images, titles):
    plt.figure(figsize=(15, 5))
    # Obs: enumerate e zip servem para iterar sobre as imagens e seus títulos simultaneamente 
    # e para obter o índice de cada imagem para posicioná-la corretamente no subplot
    for i, (img, title) in enumerate(zip(images, titles)):
        plt.subplot(1, len(images), i + 1)
        plt.imshow(img)
        plt.title(title)
        plt.axis('off')
    plt.show()

plot_images([techno, shrine, ninja], ['Techno', 'Shrine', 'Ninja'])

# %% [markdown]
# **3 -** Crie uma função que realize o escalonamento de uma imagem para que Ninja e Techno fiquem do mesmo tamanho. Utilize o método de sua preferência e mostre o resultado

# %%
(ln, cn, pn) = ninja.shape
(lt, ct, pt) = techno.shape

# printando as escalas originais
print(f"Ninja: {ln}x{cn} pixels, {pn} channels")
print(f"Techno: {lt}x{ct} pixels, {pt} channels")

# Escalonando ninja para o tamanho de techno
ninja_scale = np.zeros(shape=(lt, ct, pn), dtype=np.uint8)

# a escala é ln/lt e cn/ct 
# Near neighbor: o pixel em ninja_scale é igual ao pixel correspondente em ninja
for i in range(lt):
    for j in range(ct):
        x = int(i * ln / lt)
        y = int(j * cn / ct)
        ninja_scale[i, j] = ninja[x, y]

plot_images([ninja_scale, techno], ['Ninja Escalado', 'Techno Original'])

# printando as escalas dps do escalonamento
print(f"Ninja Escalado: {ninja_scale.shape[0]}x{ninja_scale.shape[1]} pixels, {ninja_scale.shape[2]} channels")
# Out:
# Ninja: 250x250 pixels, 3 channels
# Techno: 500x500 pixels, 3 channels
# Ninja Escalado: 500x500 pixels, 3 channels

# %% [markdown]
# **4 -** Apresente o Histograma da imagem Shrine. Mostre o resultado

# %%
def histogram_gray(image):
    hist = np.zeros(256, dtype=np.int32)
    (l,c) = image.shape

    # cada posição do histograma é a quantidade de pixels com aquela intensidade (a de image[i, j])
    for i in range(l):
        for j in range(c):
            intensidade = image[i, j] # intensidade do pixel (0 a 255)
            hist[intensidade] += 1
    return hist

def show_histogram_gray(image, title):
    hist = histogram_gray(image)

    # plotando a imagem e o histograma ambos com titulo
    plt.figure(figsize=(16, 16))
    plt.subplot(2, 1, 1)
    plt.imshow(image, cmap='gray', vmin=0, vmax=255)
    plt.title(title)
    plt.axis('off')  # remover os eixos da imagem

    plt.subplot(2, 1, 2)
    plt.bar(range(256), hist)
    plt.title('Histograma')
    plt.xlabel('Intensidade')
    plt.ylabel('Frequência')
    plt.show()


def show_histogram(img, title):
    # calculando o histograma para cada canal de cor (R, G, B)
    histogram_r = histogram_gray(img[:, :, 0])
    histogram_g = histogram_gray(img[:, :, 1])
    histogram_b = histogram_gray(img[:, :, 2])

    # plotando a imagem e o histograma ambos com titulo
    plt.figure(figsize=(16, 16))
    plt.subplot(2, 1, 1)
    plt.imshow(img, cmap='gray', vmin=0, vmax=255)
    plt.title(title)
    plt.axis('off')  # remover os eixos da imagem

    plt.subplot(2, 1, 2)
    plt.bar(range(256), histogram_r, color='red') # histograma do canal vermelho
    plt.bar(range(256), histogram_g, color='green') # histograma do canal verde
    plt.bar(range(256), histogram_b, color='blue')  # histograma do canal azul
    plt.title('Histograma')
    plt.xlabel('Intensidade')
    plt.ylabel('Frequência')
    plt.show() 

show_histogram(shrine, 'Shrine - Cores Originais')

# %% [markdown]
# **5 -** Aplique o espelhamento no eixo X à imagem techno. Mostre o resultado

# %%
# função para espelhar a imagem ninja em x
def espelhamento(img):
    (l, c, p) = img.shape
    img_espelhada = np.zeros(shape=(l, c, p), dtype=np.uint8)

    for i in range(l):
        for j in range(c):
            x = j
            y = -i

            # outra forma que nn da problema se j for 0
            #x = c - 1 - j
            # y = i

            # imagem espelhada recebe o pixel correspondente da imagem original
            img_espelhada[y,x] = img[i,j]
    return img_espelhada

techno_espelhada = espelhamento(techno)
plot_images([techno_espelhada, techno], ['Techno Espelhada', 'Techno Escalada'])

# %% [markdown]
# **6 -** Realize a operação lógica *blending* entre a imagem gerada na Questão 3 e gerada na Questão 5, com o grau de influência de 50% em ambas. Mostre o resultado

# %%
blend_espelhada_escalada = (techno_espelhada.astype(np.float32)*0.5 + ninja_scale.astype(np.float32)*0.5).astype(np.uint8)

plt.imshow(blend_espelhada_escalada)
plt.title('Blend da Techno Espelhada e Techno Escalada')
plt.axis('off')
plt.show()

# %% [markdown]
# **7 -** Depois, aplique a operação NOT na imagem Shrine. Mostre o resultado

# %%
shrine_not = np.invert(shrine)
plot_images([shrine, shrine_not], ['Shrine Original', 'Shrine Negativo'])

# %% [markdown]
# **8 -** Crie uma função para transformar imagem RGB em CMY

# %%
def rgb_to_cmy(img):
    # CMY é o inverso de RGB
    (l, c, p) = img.shape
    cmy = np.zeros(shape=(l, c, p), dtype=float)

    cmy = 1 - img

    return cmy

# %% [markdown]
# **9 -** Aplique a imagem da **questão 6 à função feita na questão 8**. Mostre o resultado

# %%
cmy_blend = rgb_to_cmy(blend_espelhada_escalada)

plt.imshow(cmy_blend)
plt.title('Blend ninja e techno em CMY')
plt.axis('off')
plt.show()

# %% [markdown]
# **10 -** Aplique a operação OR com a imagem resultante da questão 9 e questão 7, após isso salve a imagem  no disco com o nome "resultado1.jpg"

# %%
shrine_or_cmy_blend = np.bitwise_or(cmy_blend, shrine_not)
plt.imshow(shrine_or_cmy_blend)
plt.title('Shrine OR Blend CMY')
plt.axis('off')
plt.show()

Image.fromarray(shrine_or_cmy_blend).save('resultado1.png')

# %% [markdown]
# **11 -** Aplique detecção de bordas usando NumPy com a imagem resultante da questão 10, após isso salve a imagem no disco com o nome "resultado2.jpg"

# %%
# detectando as bordas
# calculando a diferença entre os pixels adjacentes em ambas as direções (horizontal e vertical)
# tg_c é a componente vertical do vetor tangente, tg_l é a componente horizontal

l, c, p = shrine_or_cmy_blend.shape



# outra opção:
resultado_2 = np.mean(shrine_or_cmy_blend, axis=2).astype(np.uint8)

abs_tg_c = np.abs(np.diff(resultado_2.astype(np.float64), axis=0, append=255))
abs_tg_l = np.abs(np.diff(resultado_2.astype(np.float64), axis=1, append=255))

# abs_tg é a magnitude do vetor tangente, ou, a raiz quadrada da soma dos quadrados das componentes
abs_tg = np.sqrt(abs_tg_c**2 + abs_tg_l**2)

borders = np.zeros(shape=resultado_2.shape, dtype=np.uint8)

threshold = 16
borders[abs_tg > threshold] = 255

plt.imshow(borders, cmap='gray')
plt.title('Bordas detectadas')
plt.axis('off')

# salvando a imagem
Image.fromarray(borders).save('resultado2.png')

# %% [markdown]
# # Lembre de entregar tudo como um arquivo ZIP, com o arquivo resultado e seu notebook, NOMEADO COMO: "C09 - LX - SEU NOME COMPLETO"
